# %% [markdown]
# # Jour 1
#
# ## Installation de python
#
# * il ne faut pas oublier de cocher la case `ajouter au PATH`
#
#
# ## Environnement virtuels
#
# Très pratique pour :
# * isoler les environnements de développement
# * connaitre les version des bibliothèques
# * permettre d'avoir des projets avec des versions de dépendances différentes
#
# ## Utilisation
#
# * création (une fois) : `python -m venv NOM_DU_VENV`
# * activation (à chaque fois)
#     * Windows : `NOM_DU_VENV\Scripts\activate.bat`
#     * MINGW : `source NOM_DU_VENV/Scripts/activate`
#     * UNIX (linux, macOS) : `source NOM_DU_VENV/bin/activate`
# * désactivation :
#     * dans tous les cas, fermer la fenetre désactive le virtualenv
#     * UNIX `deactivate`
#     * windows : `NOM_DU_VENV\Scripts\deactivate`
#
#
# ## Bibliothèques graphiques
#
# * https://plotly.com/
# * matplotlib

# %% [markdown]
# ## Intérêt de jupyter
#
# Les jupyter notebooks sont utilisés dans :
# * l'analyse exploratoire de données
# * l'éducation
#
# L'intérêt de jupyter réside dans la `programmation littérale` (code, explication, résultats sont au même endroit).

# %% [markdown]
# ### Exemple d'analyse avec jupyter

# %% [markdown]
# On peut clairement voir le niveau de progression des élèves

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
plt.plot([1, 2, 4, 9, 16])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Configuration de vscode
#
# * on utilise le mode python (extension pytohn à installer)
# * plugins / configuration
#     * formateur `black` (permet de respecter la PEP 8 : https://peps.python.org/pep-0008/)
#         * dans les paramètres de vscode change : `Editor: Format On Save` et `Python › Formatting: Provider` sur `black`
#     * linters
#         * `Python › Linting: Lint On Save`
#         * mypy : `Python › Linting: Mypy Enabled `
#         * pylint :
#             * pour modifier les warnings relevés on peut changer la config (https://stackoverflow.com/questions/7877522/how-do-i-disable-missing-docstring-warnings-at-a-file-level-in-pylint)

# %% [markdown]
# # Boucles

# %%
lines = ["a", "#", 'b']

for line in lines:
    if line.startswith("#") or "b" in line: 
        continue
    print(line)
    
for line in lines:
    if not line.startswith("#") and not "b" in line:
        print(line)
# Out:
# a
# a

# %%
[i*2 for i in range(10) if i < 4]
# Out:
# [0, 2, 4, 6]

# %%
age = 17

if age < 18:
    print("mineur")
elif age == 18:
    print("18 ans")
else:
    print("majeur")
# Out:
# mineur

# %%
age % 2 == 0
# Out:
# False

# %%
var_a = "fizz" 
var_b = ""

var_a + var_b
# Out:
# 'fizz'
